# %%
# introduction to what the game is about
print('This is a Guess Game')
print('The Game has three levels')
print('Easy')
print('Medium')
print('Hard')

#Recieving input from user
level = input('Select a level: ').lower()


# Giving specific number of trials for a particular level selected.
if level == 'easy':
  print('You have five trails')
elif level == 'medium':
  trails = 3
  print('You have three trails')
elif level == 'hard':
  trails = 2
  print('You have two trails')
else:
  print('Please select the right level to play this game')

# %%
#import random as r
#num = r.randint(0,100)
num = 20
counter = 0
while counter < trails:
  guess_num = int(input('Guess a number: '))
  counter +=1
  if guess_num == num:
    print('EXCELLENT... YOU GUESSED RIGHT')
    break
  elif num - guess_num in range(0,6):
    print('That was quite close! You are just a little smaller than the number')
  elif num - guess_num < 5:
    print('That is small')
  elif guess_num - num in range(0,6):
    print('That was close! You are just a little bigger than the number')
  elif guess_num - num > 5:
    print('That is big')
  else:
    print('Its over')
    print('You lost')

if counter == trails and guess_num != num:
  print('SORRY, YOU LOST')
  print(f'but the right answer was,{num}').4

# %%
########## ThIS IS THE PREVIOUS CODE
# import random as r
# num = r.randint(0,100)
# counter = 0
# while counter < trails:
#   guess_num = int(input('Guess a number: '))
#   counter +=1
#   if guess_num == num:
#     print('EXCELLENT... YOU GUESSED RIGHT')
#     break
#   elif num - guess_num <= int(5):
#     print('That was quite low')
#     #y == (num - guess_num <= 5)
#   elif num - guess_num == num - 5 :
#     print('Too small')
#   elif guess_num - num >= int(5):
#     print('That was close,you are a little bigger than the number')
#     #x = guess_num - num >= 5                 ##### I need to wrok on this what I want is if the guesnum about 5 bigger than the number
#   elif guess_num - num > guess_num + 5:
#     print('Too big')
#   else:
#     print('Its over')
#     print('You lost')


# if counter == trails and guess_num != num:
#   print('SORRY, YOU LOST')
#   print(f'but the right answer was,{num}')

# %%
# importing random module
#import random as r

# introduction to what the game is about
print('This is a Guess Game')
print('The Game has three levels')
print('Easy')
print('Medium')
print('Hard')

#Recieving input from user
level = input('Select a level: ').lower()

# Giving specific number of trials for a particular level selected.
if level == 'easy':
  trails = 5
  print('You have five trails')
elif level == 'medium':
  trails = 3
  print('You have three trails')
elif level == 'hard':
  trails = 2
  print('You have two trails')
else:
  print('Please select the right level to play this game')


#num = r.randint(0,100)
num = 15
counter = 0
while counter < trails:
  guess_num = int(input('Guess a number: '))
  counter +=1
  if guess_num == num:
    print('EXCELLENT... YOU GUESSED RIGHT')
    break
  elif num - guess_num in range(0,6):
    print('That was quite close! You are just a little smaller than the number')
  elif 10 <= num - guess_num <= 50:
    print('That is small')
  elif guess_num - num in range(0,6):
    print('That was close! You are just a little bigger than the number')
  elif guess_num - num > 5:
    print('That is big')
  else:
    print('Its over')
    print('You lost')

if counter == trails and guess_num != num:
  print('SORRY, YOU LOST')
  print(f'but the right answer was,{num}')
# Out:
# This is a Guess Game
# The Game has three levels
# Easy
# Medium
# Hard
# Select a level: easy
# You have five trails
# Guess a number: 4
# That is small
# Guess a number: 10
# That was quite close! You are just a little smaller than the number
# Guess a number: 17
# That was close! You are just a little bigger than the number
# Guess a number: 16
# That was close! You are just a little bigger than the number
# Guess a number: 18
# That was close! You are just a little bigger than the number
# Guess a number: 40
# That is big
